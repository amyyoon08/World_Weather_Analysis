# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime
# Import the API key.
from config import g_key
from config import weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Starting URL for Weather Map API Call.
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.

# %%
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 709

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | zhangjiakou
# Processing Record 3 of Set 1 | hermanus
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | castro
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | clyde river
# Processing Record 9 of Set 1 | suihua
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | roald
# Processing Record 12 of Set 1 | constitucion
# Processing Record 13 of Set 1 | souillac
# Processing Record 14 of Set 1 | pevek
# Processing Record 15 of Set 1 | beringovskiy
# Processing Record 16 of Set 1 | guilin
# Processing Record 17 of Set 1 | bubaque
# Processing Record 18 of Set 1 | ostrovnoy
# Processing Record 19 of Set 1 | buta
# Processing Record 20 of Set 1 | kodiak
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | saint-philippe
# Processing Record 23 of Set 1 | nome
# Processing Record 24 of Set 1 | mount gambier
# Processing Record 25 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 1 | bambous virieux
# Processing Record 27 of Set 1 | hithadhoo
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | dikson
# Processing Record 30 of Set 1 | custoias
# Processing Record 31 of Set 1 | tiznit
# Processing Record 32 of Set 1 | nandu
# Processing Record 33 of Set 1 | inderborskiy
# City not found. Skipping...
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | sao filipe
# Processing Record 36 of Set 1 | iqaluit
# Processing Record 37 of Set 1 | staraya mayna
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 1 | lebu
# Processing Record 41 of Set 1 | beidao
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | southbridge
# Processing Record 44 of Set 1 | marabba
# Processing Record 45 of Set 1 | usinsk
# Processing Record 46 of Set 1 | qaanaaq
# Processing Record 47 of Set 1 | coihaique
# Processing Record 48 of Set 1 | port moresby
# Processing Record 49 of Set 1 | tiksi
# Processing Record 50 of Set 1 | fereydunshahr
# Processing Record 1 of Set 2 | cusuna
# Processing Record 2 of Set 2 | faya
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | mataura
# Processing Record 5 of Set 2 | rikitea
# Processing Record 6 of Set 2 | kruisfontein
# Processing Record 7 of Set 2 | virginia beach
# Processing Record 8 of Set 2 | hasaki
# Processing Record 9 of Set 2 | kaitangata
# Processing Record 10 of Set 2 | taltal
# Processing Record 11 of Set 2 | strezhevoy
# Processing Record 12 of Set 2 | tenenkou
# Processing Record 13 of Set 2 | nuuk
# Processing Record 14 of Set 2 | quatre cocos
# Processing Record 15 of Set 2 | hami
# Processing Record 16 of Set 2 | callaguip
# Processing Record 17 of Set 2 | teguise
# Processing Record 18 of Set 2 | lidkoping
# Processing Record 19 of Set 2 | pichayevo
# Processing Record 20 of Set 2 | thompson
# Processing Record 21 of Set 2 | islamabad
# Processing Record 22 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 2 | yangambi
# Processing Record 24 of Set 2 | avarua
# Processing Record 25 of Set 2 | ossora
# Processing Record 26 of Set 2 | port alfred
# Processing Record 27 of Set 2 | saint-pierre
# Processing Record 28 of Set 2 | upernavik
# Processing Record 29 of Set 2 | ixtapa
# Processing Record 30 of Set 2 | kavieng
# Processing Record 31 of Set 2 | hilo
# Processing Record 32 of Set 2 | new norfolk
# Processing Record 33 of Set 2 | komsomolskiy
# Processing Record 34 of Set 2 | carnarvon
# Processing Record 35 of Set 2 | jubayl
# City not found. Skipping...
# Processing Record 36 of Set 2 | ancud
# Processing Record 37 of Set 2 | vila franca do campo
# Processing Record 38 of Set 2 | sitka
# Processing Record 39 of Set 2 | jamestown
# Processing Record 40 of Set 2 | yeletskiy
# City not found. Skipping...
# Processing Record 41 of Set 2 | cabo san lucas
# Processing Record 42 of Set 2 | boddam
# Processing Record 43 of Set 2 | wanning
# Processing Record 44 of Set 2 | luwuk
# Processing Record 45 of Set 2 | saskylakh
# Processing Record 46 of Set 2 | geraldton
# Processing Record 47 of Set 2 | ugoofaaru
# Processing Record 48 of Set 2 | hambantota
# Processing Record 49 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 2 | talnakh
# Processing Record 1 of Set 3 | ilulissat
# Processing Record 2 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 3 | jiaohe
# Processing Record 4 of Set 3 | gdov
# Processing Record 5 of Set 3 | peniche
# Processing Record 6 of Set 3 | tuktoyaktuk
# Processing Record 7 of Set 3 | altinopolis
# Processing Record 8 of Set 3 | mar del plata
# Processing Record 9 of Set 3 | port lincoln
# Processing Record 10 of Set 3 | nemuro
# Processing Record 11 of Set 3 | lavrentiya
# Processing Record 12 of Set 3 | nikolskoye
# Processing Record 13 of Set 3 | saint combs
# City not found. Skipping...
# Processing Record 14 of Set 3 | longyearbyen
# Processing Record 15 of Set 3 | chokurdakh
# Processing Record 16 of Set 3 | ahipara
# Processing Record 17 of Set 3 | derzhavinsk
# Processing Record 18 of Set 3 | bredasdorp
# Processing Record 19 of Set 3 | seoul
# Processing Record 20 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 3 | maicao
# Processing Record 22 of Set 3 | charters towers
# Processing Record 23 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 3 | la troncal
# Processing Record 25 of Set 3 | vestmannaeyjar
# Processing Record 26 of Set 3 | soyo
# Processing Record 27 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 3 | cabedelo
# Processing Record 29 of Set 3 | saldanha
# Processing Record 30 of Set 3 | galgani
# City not found. Skipping...
# Processing Record 31 of Set 3 | bac lieu
# Processing Record 32 of Set 3 | blagoyevo
# Processing Record 33 of Set 3 | abu road
# Processing Record 34 of Set 3 | yellowknife
# Processing Record 35 of Set 3 | vanimo
# Processing Record 36 of Set 3 | tasiilaq
# Processing Record 37 of Set 3 | faanui
# Processing Record 38 of Set 3 | kuminskiy
# Processing Record 39 of Set 3 | lagoa
# Processing Record 40 of Set 3 | kisangani
# Processing Record 41 of Set 3 | temaraia
# City not found. Skipping...
# Processing Record 42 of Set 3 | puerto ayora
# Processing Record 43 of Set 3 | arraial do cabo
# Processing Record 44 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 3 | atar
# Processing Record 46 of Set 3 | andenes
# Processing Record 47 of Set 3 | okhotsk
# Processing Record 48 of Set 3 | yumen
# Processing Record 49 of Set 3 | alofi
# Processing Record 50 of Set 3 | saint george
# Processing Record 1 of Set 4 | aksarka
# Processing Record 2 of Set 4 | touros
# Processing Record 3 of Set 4 | chuy
# Processing Record 4 of Set 4 | tongchuan
# Processing Record 5 of Set 4 | provideniya
# Processing Record 6 of Set 4 | cockburn town
# Processing Record 7 of Set 4 | pinega
# Processing Record 8 of Set 4 | shenjiamen
# Processing Record 9 of Set 4 | adrar
# Processing Record 10 of Set 4 | derbent
# Processing Record 11 of Set 4 | pedasi
# Processing Record 12 of Set 4 | jagdalpur
# Processing Record 13 of Set 4 | sechura
# Processing Record 14 of Set 4 | katsuura
# Processing Record 15 of Set 4 | tikrit
# Processing Record 16 of Set 4 | ribeira grande
# Processing Record 17 of Set 4 | sorland
# Processing Record 18 of Set 4 | marion
# Processing Record 19 of Set 4 | asosa
# Processing Record 20 of Set 4 | alice springs
# Processing Record 21 of Set 4 | kushmurun
# Processing Record 22 of Set 4 | marsaxlokk
# Processing Record 23 of Set 4 | east london
# Processing Record 24 of Set 4 | codrington
# Processing Record 25 of Set 4 | lorengau
# Processing Record 26 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 27 of Set 4 | shvartsevskiy
# Processing Record 28 of Set 4 | san jose
# Processing Record 29 of Set 4 | macaboboni
# City not found. Skipping...
# Processing Record 30 of Set 4 | vila velha
# Processing Record 31 of Set 4 | oksfjord
# Processing Record 32 of Set 4 | acarau
# Processing Record 33 of Set 4 | bontang
# Processing Record 34 of Set 4 | paulo afonso
# Processing Record 35 of Set 4 | turukhansk
# Processing Record 36 of Set 4 | novikovo
# Processing Record 37 of Set 4 | guatire
# Processing Record 38 of Set 4 | nyagan
# Processing Record 39 of Set 4 | gimli
# Processing Record 40 of Set 4 | caldwell
# Processing Record 41 of Set 4 | kailua
# Processing Record 42 of Set 4 | tuatapere
# Processing Record 43 of Set 4 | clinton
# Processing Record 44 of Set 4 | kostino
# Processing Record 45 of Set 4 | christchurch
# Processing Record 46 of Set 4 | labrea
# Processing Record 47 of Set 4 | nizhniy kuranakh
# Processing Record 48 of Set 4 | general roca
# Processing Record 49 of Set 4 | tilichiki
# Processing Record 50 of Set 4 | norman wells
# Processing Record 1 of Set 5 | salalah
# Processing Record 2 of Set 5 | ponta do sol
# Processing Record 3 of Set 5 | asyut
# Processing Record 4 of Set 5 | port elizabeth
# Processing Record 5 of Set 5 | aklavik
# Processing Record 6 of Set 5 | butaritari
# Processing Record 7 of Set 5 | bagdarin
# Processing Record 8 of Set 5 | baykit
# Processing Record 9 of Set 5 | bethel
# Processing Record 10 of Set 5 | klaksvik
# Processing Record 11 of Set 5 | cherskiy
# Processing Record 12 of Set 5 | kemijarvi
# Processing Record 13 of Set 5 | ambanja
# Processing Record 14 of Set 5 | baltay
# Processing Record 15 of Set 5 | sambava
# Processing Record 16 of Set 5 | juanjui
# Processing Record 17 of Set 5 | druzhba
# Processing Record 18 of Set 5 | san cristobal
# Processing Record 19 of Set 5 | lahat
# Processing Record 20 of Set 5 | swan hill
# Processing Record 21 of Set 5 | huangnihe
# Processing Record 22 of Set 5 | grand gaube
# Processing Record 23 of Set 5 | udachnyy
# Processing Record 24 of Set 5 | dabou
# Processing Record 25 of Set 5 | kutum
# Processing Record 26 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 27 of Set 5 | praia da vitoria
# Processing Record 28 of Set 5 | kalmunai
# Processing Record 29 of Set 5 | keti bandar
# Processing Record 30 of Set 5 | yinchuan
# Processing Record 31 of Set 5 | kaduqli
# Processing Record 32 of Set 5 | taldan
# Processing Record 33 of Set 5 | urdzhar
# City not found. Skipping...
# Processing Record 34 of Set 5 | ormara
# Processing Record 35 of Set 5 | nhulunbuy
# Processing Record 36 of Set 5 | arman
# Processing Record 37 of Set 5 | puerto lleras
# Processing Record 38 of Set 5 | tura
# Processing Record 39 of Set 5 | mucuri
# Processing Record 40 of Set 5 | chapais
# Processing Record 41 of Set 5 | vaitape
# Processing Record 42 of Set 5 | kurilsk
# Processing Record 43 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 5 | san patricio
# Processing Record 45 of Set 5 | shagonar
# Processing Record 46 of Set 5 | manaure
# Processing Record 47 of Set 5 | miri
# Processing Record 48 of Set 5 | nanortalik
# Processing Record 49 of Set 5 | pinehurst
# Processing Record 50 of Set 5 | mahebourg
# Processing Record 1 of Set 6 | chernyshevskiy
# Processing Record 2 of Set 6 | narsaq
# Processing Record 3 of Set 6 | bow island
# Processing Record 4 of Set 6 | emerald
# Processing Record 5 of Set 6 | haines junction
# Processing Record 6 of Set 6 | stoke-on-trent
# Processing Record 7 of Set 6 | magadan
# Processing Record 8 of Set 6 | vermillion
# Processing Record 9 of Set 6 | takoradi
# Processing Record 10 of Set 6 | severo-kurilsk
# Processing Record 11 of Set 6 | barrow
# Processing Record 12 of Set 6 | tucumcari
# Processing Record 13 of Set 6 | cascais
# Processing Record 14 of Set 6 | ban nahin
# Processing Record 15 of Set 6 | zyryanovsk
# Processing Record 16 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 6 | katima mulilo
# Processing Record 18 of Set 6 | georgetown
# Processing Record 19 of Set 6 | zhigansk
# Processing Record 20 of Set 6 | shchelyayur
# City not found. Skipping...
# Processing Record 21 of Set 6 | churapcha
# Processing Record 22 of Set 6 | xiongzhou
# Processing Record 23 of Set 6 | wad rawah
# Processing Record 24 of Set 6 | tamandare
# Processing Record 25 of Set 6 | itupiranga
# Processing Record 26 of Set 6 | maniitsoq
# Processing Record 27 of Set 6 | jibuti
# Processing Record 28 of Set 6 | port huron
# Processing Record 29 of Set 6 | karratha
# Processing Record 30 of Set 6 | husavik
# Processing Record 31 of Set 6 | nyurba
# Processing Record 32 of Set 6 | dustlik
# Processing Record 33 of Set 6 | belmopan
# Processing Record 34 of Set 6 | gushi
# Processing Record 35 of Set 6 | sturgeon falls
# Processing Record 36 of Set 6 | airai
# Processing Record 37 of Set 6 | alyangula
# Processing Record 38 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 6 | divnogorsk
# Processing Record 40 of Set 6 | sao felix do xingu
# Processing Record 41 of Set 6 | itarema
# Processing Record 42 of Set 6 | olds
# Processing Record 43 of Set 6 | pulandian
# Processing Record 44 of Set 6 | lagos
# Processing Record 45 of Set 6 | samarai
# Processing Record 46 of Set 6 | viedma
# Processing Record 47 of Set 6 | bluffton
# Processing Record 48 of Set 6 | necochea
# Processing Record 49 of Set 6 | solnechnyy
# Processing Record 50 of Set 6 | yar-sale
# Processing Record 1 of Set 7 | puerto del rosario
# Processing Record 2 of Set 7 | yangshan
# Processing Record 3 of Set 7 | cayenne
# Processing Record 4 of Set 7 | khatanga
# Processing Record 5 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 6 of Set 7 | kumbo
# Processing Record 7 of Set 7 | qui nhon
# Processing Record 8 of Set 7 | lumeje
# Processing Record 9 of Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 10 of Set 7 | ambilobe
# Processing Record 11 of Set 7 | pipar
# Processing Record 12 of Set 7 | aripuana
# Processing Record 13 of Set 7 | presidencia roque saenz pena
# Processing Record 14 of Set 7 | leningradskiy
# Processing Record 15 of Set 7 | fairbanks
# Processing Record 16 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 7 | port hardy
# Processing Record 18 of Set 7 | noumea
# Processing Record 19 of Set 7 | sergeyevka
# Processing Record 20 of Set 7 | carmaux
# Processing Record 21 of Set 7 | leh
# Processing Record 22 of Set 7 | vao
# Processing Record 23 of Set 7 | douentza
# Processing Record 24 of Set 7 | hofn
# Processing Record 25 of Set 7 | san policarpo
# Processing Record 26 of Set 7 | kindu
# Processing Record 27 of Set 7 | tiarei
# Processing Record 28 of Set 7 | nohar
# Processing Record 29 of Set 7 | westport
# Processing Record 30 of Set 7 | brae
# Processing Record 31 of Set 7 | pimentel
# Processing Record 32 of Set 7 | coquimbo
# Processing Record 33 of Set 7 | bosaso
# Processing Record 34 of Set 7 | mullaitivu
# City not found. Skipping...
# Processing Record 35 of Set 7 | aswan
# Processing Record 36 of Set 7 | dunedin
# Processing Record 37 of Set 7 | taoudenni
# Processing Record 38 of Set 7 | xichang
# Processing Record 39 of Set 7 | opuwo
# Processing Record 40 of Set 7 | boca do acre
# Processing Record 41 of Set 7 | fort madison
# Processing Record 42 of Set 7 | kaufbeuren
# Processing Record 43 of Set 7 | preston
# Processing Record 44 of Set 7 | labuhan
# Processing Record 45 of Set 7 | nogales
# Processing Record 46 of Set 7 | nantucket
# Processing Record 47 of Set 7 | la rochelle
# Processing Record 48 of Set 7 | zhenjiang
# Processing Record 49 of Set 7 | peremyshlyany
# Processing Record 50 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 8 | broome
# Processing Record 3 of Set 8 | inta
# Processing Record 4 of Set 8 | berlevag
# Processing Record 5 of Set 8 | paramonga
# Processing Record 6 of Set 8 | toora-khem
# Processing Record 7 of Set 8 | leshukonskoye
# Processing Record 8 of Set 8 | urusha
# Processing Record 9 of Set 8 | gamba
# Processing Record 10 of Set 8 | kungurtug
# Processing Record 11 of Set 8 | guarapari
# Processing Record 12 of Set 8 | ibra
# Processing Record 13 of Set 8 | abha
# Processing Record 14 of Set 8 | bonavista
# Processing Record 15 of Set 8 | katsiveli
# City not found. Skipping...
# Processing Record 16 of Set 8 | paamiut
# Processing Record 17 of Set 8 | olafsvik
# Processing Record 18 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 19 of Set 8 | anaconda
# Processing Record 20 of Set 8 | niihama
# Processing Record 21 of Set 8 | kudahuvadhoo
# Processing Record 22 of Set 8 | mundo nuevo
# Processing Record 23 of Set 8 | shubarshi
# Processing Record 24 of Set 8 | west plains
# Processing Record 25 of Set 8 | arawa
# Processing Record 26 of Set 8 | fuyu
# Processing Record 27 of Set 8 | elliot lake
# Processing Record 28 of Set 8 | dongzhen
# Processing Record 29 of Set 8 | odienne
# Processing Record 30 of Set 8 | broken hill
# Processing Record 31 of Set 8 | grindavik
# Processing Record 32 of Set 8 | mamlyutka
# Processing Record 33 of Set 8 | yaritagua
# Processing Record 34 of Set 8 | haslett
# Processing Record 35 of Set 8 | khuzhir
# Processing Record 36 of Set 8 | tecoanapa
# Processing Record 37 of Set 8 | kaiserslautern
# Processing Record 38 of Set 8 | mweka
# Processing Record 39 of Set 8 | mbandaka
# Processing Record 40 of Set 8 | pasighat
# Processing Record 41 of Set 8 | gwanda
# Processing Record 42 of Set 8 | cangzhou
# Processing Record 43 of Set 8 | ostersund
# Processing Record 44 of Set 8 | abu samrah
# Processing Record 45 of Set 8 | matay
# Processing Record 46 of Set 8 | isangel
# Processing Record 47 of Set 8 | svetlyy
# Processing Record 48 of Set 8 | yining
# Processing Record 49 of Set 8 | rakai
# Processing Record 50 of Set 8 | spring hill
# Processing Record 1 of Set 9 | tinaquillo
# Processing Record 2 of Set 9 | cidreira
# Processing Record 3 of Set 9 | akyab
# Processing Record 4 of Set 9 | hamilton
# Processing Record 5 of Set 9 | las matas de farfan
# Processing Record 6 of Set 9 | calinaoan
# City not found. Skipping...
# Processing Record 7 of Set 9 | juifang
# City not found. Skipping...
# Processing Record 8 of Set 9 | biltine
# Processing Record 9 of Set 9 | ducheng
# Processing Record 10 of Set 9 | lufilufi
# Processing Record 11 of Set 9 | nea fokaia
# Processing Record 12 of Set 9 | nouadhibou
# Processing Record 13 of Set 9 | marolambo
# Processing Record 14 of Set 9 | kayan
# Processing Record 15 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 16 of Set 9 | tezu
# Processing Record 17 of Set 9 | gurgan
# City not found. Skipping...
# Processing Record 18 of Set 9 | buala
# Processing Record 19 of Set 9 | luderitz
# Processing Record 20 of Set 9 | solsvik
# City not found. Skipping...
# Processing Record 21 of Set 9 | chenove
# Processing Record 22 of Set 9 | visby
# Processing Record 23 of Set 9 | saint-felicien
# Processing Record 24 of Set 9 | kaliua
# Processing Record 25 of Set 9 | talcahuano
# Processing Record 26 of Set 9 | wagga wagga
# Processing Record 27 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 28 of Set 9 | esperance
# Processing Record 29 of Set 9 | lata
# Processing Record 30 of Set 9 | requena
# Processing Record 31 of Set 9 | havelian
# Processing Record 32 of Set 9 | krasnoselkup
# Processing Record 33 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 9 | florence
# Processing Record 35 of Set 9 | atherton
# Processing Record 36 of Set 9 | berezovka
# Processing Record 37 of Set 9 | havoysund
# Processing Record 38 of Set 9 | terra roxa
# Processing Record 39 of Set 9 | guiren
# Processing Record 40 of Set 9 | kenora
# Processing Record 41 of Set 9 | octeville
# Processing Record 42 of Set 9 | dali
# Processing Record 43 of Set 9 | kavaratti
# Processing Record 44 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 45 of Set 9 | inirida
# Processing Record 46 of Set 9 | puerto madryn
# Processing Record 47 of Set 9 | sainte-maxime
# Processing Record 48 of Set 9 | batetskiy
# Processing Record 49 of Set 9 | aksha
# Processing Record 50 of Set 9 | diamantino
# Processing Record 1 of Set 10 | cabra
# Processing Record 2 of Set 10 | caravelas
# Processing Record 3 of Set 10 | surt
# Processing Record 4 of Set 10 | ilheus
# Processing Record 5 of Set 10 | ketchikan
# Processing Record 6 of Set 10 | sakaraha
# Processing Record 7 of Set 10 | oussouye
# Processing Record 8 of Set 10 | umm lajj
# Processing Record 9 of Set 10 | flinders
# Processing Record 10 of Set 10 | zhuozhou
# City not found. Skipping...
# Processing Record 11 of Set 10 | bajo baudo
# City not found. Skipping...
# Processing Record 12 of Set 10 | mlowo
# Processing Record 13 of Set 10 | bone
# Processing Record 14 of Set 10 | caraguatatuba
# Processing Record 15 of Set 10 | rio gallegos
# Processing Record 16 of Set 10 | dinsor
# City not found. Skipping...
# Processing Record 17 of Set 10 | hokitika
# Processing Record 18 of Set 10 | ovalle
# Processing Record 19 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 10 | waipawa
# Processing Record 21 of Set 10 | dagana
# Processing Record 22 of Set 10 | salisbury
# Processing Record 23 of Set 10 | sorong
# Processing Record 24 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 10 | ushirombo
# Processing Record 26 of Set 10 | sao joao da barra
# Processing Record 27 of Set 10 | fortuna
# Processing Record 28 of Set 10 | buraydah
# Processing Record 29 of Set 10 | lasa
# Processing Record 30 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 10 | igrim
# Processing Record 32 of Set 10 | palana
# Processing Record 33 of Set 10 | portland
# Processing Record 34 of Set 10 | ust-omchug
# Processing Record 35 of Set 10 | hovd
# Processing Record 36 of Set 10 | port blair
# Processing Record 37 of Set 10 | jiroft
# City not found. Skipping...
# Processing Record 38 of Set 10 | iguape
# Processing Record 39 of Set 10 | dingle
# Processing Record 40 of Set 10 | guangshui
# Processing Record 41 of Set 10 | pisco
# Processing Record 42 of Set 10 | istanbul
# Processing Record 43 of Set 10 | biloela
# Processing Record 44 of Set 10 | tacoronte
# Processing Record 45 of Set 10 | rio grande
# Processing Record 46 of Set 10 | port keats
# Processing Record 47 of Set 10 | richards bay
# Processing Record 48 of Set 10 | sarangani
# Processing Record 49 of Set 10 | bandarbeyla
# Processing Record 50 of Set 10 | la ronge
# Processing Record 1 of Set 11 | mocuba
# Processing Record 2 of Set 11 | boyolangu
# Processing Record 3 of Set 11 | qaqortoq
# Processing Record 4 of Set 11 | lazaro cardenas
# Processing Record 5 of Set 11 | vanavara
# Processing Record 6 of Set 11 | barberton
# Processing Record 7 of Set 11 | los llanos de aridane
# Processing Record 8 of Set 11 | parvatsar
# Processing Record 9 of Set 11 | nishihara
# Processing Record 10 of Set 11 | namibe
# Processing Record 11 of Set 11 | xining
# Processing Record 12 of Set 11 | victoria
# Processing Record 13 of Set 11 | neiafu
# Processing Record 14 of Set 11 | kulykiv
# Processing Record 15 of Set 11 | haverhill
# Processing Record 16 of Set 11 | mount isa
# Processing Record 17 of Set 11 | margate
# Processing Record 18 of Set 11 | quelimane
# Processing Record 19 of Set 11 | milingimbi
# City not found. Skipping...
# Processing Record 20 of Set 11 | norsup
# Processing Record 21 of Set 11 | miranda
# Processing Record 22 of Set 11 | qingdao
# Processing Record 23 of Set 11 | mlonggo
# Processing Record 24 of Set 11 | lake havasu city
# Processing Record 25 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 26 of Set 11 | homer
# Processing Record 27 of Set 11 | nautla
# Processing Record 28 of Set 11 | taquari
# Processing Record 29 of Set 11 | disa
# Processing Record 30 of Set 11 | pimenta bueno
# Processing Record 31 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 32 of Set 11 | wuwei
# Processing Record 33 of Set 11 | muzaffarabad
# Processing Record 34 of Set 11 | okato
# Processing Record 35 of Set 11 | dakar
# Processing Record 36 of Set 11 | yulara
# Processing Record 37 of Set 11 | aporawan
# City not found. Skipping...
# Processing Record 38 of Set 11 | kipushi
# Processing Record 39 of Set 11 | cisternino
# Processing Record 40 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 41 of Set 11 | abonnema
# Processing Record 42 of Set 11 | pitimbu
# Processing Record 43 of Set 11 | pinyug
# Processing Record 44 of Set 11 | the valley
# Processing Record 45 of Set 11 | kashi
# Processing Record 46 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 47 of Set 11 | bantry
# Processing Record 48 of Set 11 | bilma
# Processing Record 49 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 50 of Set 11 | henties bay
# Processing Record 1 of Set 12 | algiers
# Processing Record 2 of Set 12 | bacuit
# City not found. Skipping...
# Processing Record 3 of Set 12 | kazanka
# Processing Record 4 of Set 12 | atasu
# Processing Record 5 of Set 12 | ho
# City not found. Skipping...
# Processing Record 6 of Set 12 | bolobo
# Processing Record 7 of Set 12 | nizhniy tsasuchey
# Processing Record 8 of Set 12 | lao cai
# Processing Record 9 of Set 12 | pervomayskoye
# Processing Record 10 of Set 12 | cap malheureux
# Processing Record 11 of Set 12 | karlskoga
# Processing Record 12 of Set 12 | tirumullaivasal
# Processing Record 13 of Set 12 | hvide sande
# Processing Record 14 of Set 12 | guelengdeng
# City not found. Skipping...
# Processing Record 15 of Set 12 | mayo
# Processing Record 16 of Set 12 | trinidad
# Processing Record 17 of Set 12 | mbumi
# Processing Record 18 of Set 12 | pangkalanbuun
# Processing Record 19 of Set 12 | seymchan
# Processing Record 20 of Set 12 | antalaha
# Processing Record 21 of Set 12 | naze
# Processing Record 22 of Set 12 | tecpan
# Processing Record 23 of Set 12 | bengkulu
# Processing Record 24 of Set 12 | golden
# Processing Record 25 of Set 12 | stadtbergen
# Processing Record 26 of Set 12 | tatarsk
# Processing Record 27 of Set 12 | carlsbad
# Processing Record 28 of Set 12 | san luis
# Processing Record 29 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 12 | ozernovskiy
# Processing Record 31 of Set 12 | kohila
# Processing Record 32 of Set 12 | tocopilla
# Processing Record 33 of Set 12 | denpasar
# Processing Record 34 of Set 12 | acari
# Processing Record 35 of Set 12 | altamira
# Processing Record 36 of Set 12 | tottori
# Processing Record 37 of Set 12 | mildura
# Processing Record 38 of Set 12 | san quintin
# Processing Record 39 of Set 12 | hobara
# Processing Record 40 of Set 12 | omsukchan
# Processing Record 41 of Set 12 | odweyne
# Processing Record 42 of Set 12 | waddan
# Processing Record 43 of Set 12 | evensk
# Processing Record 44 of Set 12 | maarianhamina
# Processing Record 45 of Set 12 | praia
# Processing Record 46 of Set 12 | camabatela
# Processing Record 47 of Set 12 | menongue
# Processing Record 48 of Set 12 | sokolo
# Processing Record 49 of Set 12 | santa rosalia
# Processing Record 50 of Set 12 | high level
# Processing Record 1 of Set 13 | leninskoye
# Processing Record 2 of Set 13 | tabas
# Processing Record 3 of Set 13 | san rafael
# Processing Record 4 of Set 13 | black river
# Processing Record 5 of Set 13 | cukai
# Processing Record 6 of Set 13 | pindushi
# Processing Record 7 of Set 13 | gogrial
# Processing Record 8 of Set 13 | pustoshka
# Processing Record 9 of Set 13 | gallup
# Processing Record 10 of Set 13 | cantapoy
# Processing Record 11 of Set 13 | juegang
# Processing Record 12 of Set 13 | ferme-neuve
# Processing Record 13 of Set 13 | aykhal
# Processing Record 14 of Set 13 | tongliao
# Processing Record 15 of Set 13 | marsh harbour
# Processing Record 16 of Set 13 | bayeux
# Processing Record 17 of Set 13 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 13 | itaqui
# Processing Record 19 of Set 13 | santa fe
# Processing Record 20 of Set 13 | la asuncion
# Processing Record 21 of Set 13 | algeciras
# Processing Record 22 of Set 13 | bilibino
# Processing Record 23 of Set 13 | saint anthony
# Processing Record 24 of Set 13 | salinas
# Processing Record 25 of Set 13 | kenai
# Processing Record 26 of Set 13 | nioro
# Processing Record 27 of Set 13 | moussoro
# Processing Record 28 of Set 13 | vestmanna
# Processing Record 29 of Set 13 | turayf
# Processing Record 30 of Set 13 | sassandra
# Processing Record 31 of Set 13 | fenoarivo
# Processing Record 32 of Set 13 | port macquarie
# Processing Record 33 of Set 13 | pundaguitan
# Processing Record 34 of Set 13 | jinchang
# Processing Record 35 of Set 13 | mitsamiouli
# Processing Record 36 of Set 13 | kargil
# Processing Record 37 of Set 13 | high wycombe
# Processing Record 38 of Set 13 | lac du bonnet
# Processing Record 39 of Set 13 | sitangkai
# Processing Record 40 of Set 13 | mokhsogollokh
# Processing Record 41 of Set 13 | nesbyen
# Processing Record 42 of Set 13 | sur
# Processing Record 43 of Set 13 | amarante do maranhao
# Processing Record 44 of Set 13 | laguna
# Processing Record 45 of Set 13 | rosetta
# Processing Record 46 of Set 13 | camacha
# Processing Record 47 of Set 13 | carberry
# Processing Record 48 of Set 13 | tallahassee
# Processing Record 49 of Set 13 | dicabisagan
# Processing Record 50 of Set 13 | blackpool
# Processing Record 1 of Set 14 | palu
# Processing Record 2 of Set 14 | majene
# Processing Record 3 of Set 14 | jasper
# Processing Record 4 of Set 14 | wodonga
# Processing Record 5 of Set 14 | nadaun
# Processing Record 6 of Set 14 | lithakia
# Processing Record 7 of Set 14 | ambon
# Processing Record 8 of Set 14 | uwayl
# City not found. Skipping...
# Processing Record 9 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 10 of Set 14 | vangaindrano
# Processing Record 11 of Set 14 | banda aceh
# Processing Record 12 of Set 14 | klyuchi
# Processing Record 13 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 14 of Set 14 | havre-saint-pierre
# Processing Record 15 of Set 14 | mamou
# Processing Record 16 of Set 14 | oranjemund
# Processing Record 17 of Set 14 | vallenar
# Processing Record 18 of Set 14 | joshimath
# Processing Record 19 of Set 14 | manokwari
# Processing Record 20 of Set 14 | megion
# Processing Record 21 of Set 14 | elmadag
# Processing Record 22 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 23 of Set 14 | lesnyye polyany
# Processing Record 24 of Set 14 | malakal
# Processing Record 25 of Set 14 | belmonte
# Processing Record 26 of Set 14 | orel
# Processing Record 27 of Set 14 | harda
# Processing Record 28 of Set 14 | vicuna
# Processing Record 29 of Set 14 | ampere
# Processing Record 30 of Set 14 | mattru
# Processing Record 31 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 14 | wilhelmshaven
# Processing Record 33 of Set 14 | emmett
# Processing Record 34 of Set 14 | hualmay
# Processing Record 35 of Set 14 | san lorenzo
# Processing Record 36 of Set 14 | armacao dos buzios
# City not found. Skipping...
# Processing Record 37 of Set 14 | zambezi
# Processing Record 38 of Set 14 | terrace
# Processing Record 39 of Set 14 | abu dhabi
# Processing Record 40 of Set 14 | suratgarh
# Processing Record 41 of Set 14 | makhachkala
# Processing Record 42 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 44 of Set 14 | mayor pablo lagerenza
# Processing Record 45 of Set 14 | domasnea
# Processing Record 46 of Set 14 | jati
# Processing Record 47 of Set 14 | kaka
# Processing Record 48 of Set 14 | torbay
# Processing Record 49 of Set 14 | kota
# Processing Record 50 of Set 14 | parnu
# Processing Record 1 of Set 15 | batagay
# Processing Record 2 of Set 15 | guerrero negro
# Processing Record 3 of Set 15 | madison
# Processing Record 4 of Set 15 | amalapuram
# Processing Record 5 of Set 15 | loveland
# Processing Record 6 of Set 15 | bjornevatn
# Processing Record 7 of Set 15 | abu kamal
# Processing Record 8 of Set 15 | pointe-noire
# Processing Record 9 of Set 15 | namatanai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Zhangjiakou      CN  40.8100  114.8794     30.18        84         100
# 1     Hermanus      ZA -34.4187   19.2345     73.00        81           0
# 2       Albany      US  42.6001  -73.9662     43.00        58         100
# 3       Castro      BR -24.7911  -50.0119     67.26        92          26
# 4      Ushuaia      AR -54.8000  -68.3000     50.00        57          40
# 5        Kapaa      US  22.0752 -159.3190     75.20        73          75
# 6  Clyde River      CA  70.4692  -68.5914    -31.00        75           1
# 7       Suihua      CN  46.6406  126.9969     -3.44        91         100
# 8    Busselton      AU -33.6500  115.3333     63.00        79         100
# 9        Roald      NO  62.5833    6.1333     42.80        87          75
#
#    Wind Speed Current Description
# 0        5.32     overcast clouds
# 1        7.00           clear sky
# 2       11.36     overcast clouds
# 3        9.86    scattered clouds
# 4       23.02    scattered clouds
# 5       20.71          light rain
# 6        5.75           clear sky
# 7        7.02     overcast clouds
# 8        1.01     overcast clouds
# 9       26.46       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# End Code. Thank You!
